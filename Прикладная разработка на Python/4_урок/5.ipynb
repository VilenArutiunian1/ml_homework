# %%
import numpy as np

def dot_product(vec1, vec2):
    if len(vec1) != len(vec2):
        return None
    s = 0
    for i in range(0, len(vec1)):
        s += (vec1[i] * vec2[i])

    return s

vec1 = list(range(int(1e5)))
vec2 = list(range(int(1e5)))
print("{:.2e}".format(dot_product(vec1, vec2)))

# для 7 задания
vec1 = np.array(range(int(1e5)))
vec2 = np.array(range(int(1e5)))
# Out:
# 3.33e+14

# %%
# %%timeit

np.dot(vec1, vec2)
# Out:
# 129 μs ± 35.9 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
